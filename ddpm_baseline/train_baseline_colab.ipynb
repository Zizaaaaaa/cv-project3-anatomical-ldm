# %%
# !pip install diffusers accelerate

# %%
# !unzip processed_patches_stage4.zip
# Out:
# Archive:  processed_patches_stage4.zip
# replace processed_patches_stage4/Image154_patch_3_loss_46.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_0.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_1.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_2.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_3.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_4.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_5.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_6.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_7.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_8.png
#   inflating: processed_patches_stage4/Image154_patch_3_loss_46_aug_9.png
# ...

# %%
# !python train_baseline.py
# Out:
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Starting training on cuda...
# Epoch 1/50: 100% 34/34 [02:00<00:00,  3.53s/it, loss=0.095]
# Epoch 1/50: 100% 34/34 [02:00<00:00,  3.54s/it, loss=0.095]
#
# Epoch 2/50:   3% 1/34 [00:01<00:41,  1.26s/it]
# Epoch 2/50:   3% 1/34 [00:03<00:41,  1.26s/it, loss=0.155]
# Epoch 2/50:   6% 2/34 [00:04<01:26,  2.70s/it, loss=0.155]
# Epoch 2/50:   6% 2/34 [00:07<01:26,  2.70s/it, loss=0.0888]
# Epoch 2/50:   9% 3/34 [00:08<01:37,  3.15s/it, loss=0.0888]
# Epoch 2/50:   9% 3/34 [00:11<01:37,  3.15s/it, loss=0.108]
# Epoch 2/50:  12% 4/34 [00:12<01:40,  3.35s/it, loss=0.108]
# Epoch 2/50:  12% 4/34 [00:14<01:40,  3.35s/it, loss=0.0819]
# ...
